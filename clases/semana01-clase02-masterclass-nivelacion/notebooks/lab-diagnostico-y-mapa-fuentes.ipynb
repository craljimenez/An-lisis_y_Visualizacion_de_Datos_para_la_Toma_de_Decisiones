# %% [markdown]
# # Laboratorio — Diagnóstico y mapa de fuentes
# ### Semana 1 · Clase 2 — MasterClass (Nivelación)
# **Curso:** Análisis y Visualización de Datos para la Toma de Decisiones (Esumer)
#
# **Objetivo de esta hora:**
# 1. Autodiagnóstico rápido de los conceptos de la Clase 1.
# 2. Mapear las fuentes de datos de tu proyecto integrador.
# 3. Redactar tu **problema y pregunta analítica inicial**, con el framework de hoy.
#
# > Este notebook usa muy poco código a propósito — todavía no hemos visto
# > Python a fondo (eso empieza en la Clase 4). Hoy el foco es pensar y
# > escribir claro sobre *tu* caso.

# %% [markdown]
# ## 1. Autodiagnóstico rápido
#
# Califica tu confianza en cada tema de la Clase 1, de 1 (nada seguro) a 5
# (muy seguro). No hay respuesta incorrecta — es solo para que tú y el
# docente sepan dónde reforzar.

# %%
autodiagnostico = {
    "Explico qu\u00e9 es la pir\u00e1mide DIKW (datos-informaci\u00f3n-conocimiento-sabidur\u00eda)": None,
    "Explico el ciclo de vida del dato": None,
    "Distingo datos estructurados de no estructurados": None,
    "S\u00e9 qu\u00e9 revisar para juzgar la calidad de un dato": None,
    "Distingo un problema de negocio de una pregunta anal\u00edtica": None,
}

# TODO: reemplaza cada None por un n\u00famero del 1 al 5
print(autodiagnostico)

# %%
valores = [v for v in autodiagnostico.values() if v is not None]
if valores:
    promedio = sum(valores) / len(valores)
    print(f"Tu promedio de confianza: {promedio:.1f} / 5")
    if promedio < 3:
        print("Tranquilo: para eso estamos repasando hoy. Pregunta sin pena.")
    else:
        print("¡Buena base! Hoy profundizamos un poco más.")
else:
    print("Completa el diagnóstico de arriba primero.")

# %% [markdown]
# ## 2. Mapa de fuentes de datos de tu proyecto
#
# Piensa en un problema real de tu entorno laboral o académico (el que
# trajiste de tarea). Completa la tabla con **al menos 4 fuentes de datos**
# que podrías usar para abordarlo — mezcla fuentes internas y externas si
# puedes.

# %%
import pandas as pd

mapa_fuentes = pd.DataFrame([
    # Ejemplo ya resuelto — no lo borres, solo agrega tus propias filas debajo.
    {
        "fuente": "Sistema de ventas (POS)",
        "tipo": "interna",
        "formato": "estructurada",
        "disponibilidad": "alta",
    },
    # TODO: agrega tus propias fuentes, una por fila, con las mismas 4 columnas.
    # {"fuente": "...", "tipo": "interna/externa", "formato": "estructurada/no estructurada", "disponibilidad": "alta/media/baja"},
])

mapa_fuentes

# %% [markdown]
# ## 3. Tu problema y pregunta analítica inicial
#
# Usa el mismo framework de la clase: **Contexto → Problema → Pregunta
# analítica → Datos necesarios → Métrica de éxito**. Sé lo más concreto
# posible (revisa la diapositiva "¿Cómo formular un problema de negocio?"
# de la Clase 1 si tienes dudas).

# %%
mi_proyecto = {
    "contexto": "",           # TODO: ¿de qué organización/área hablamos?
    "problema": "",           # TODO: ¿qué está pasando que no debería?
    "pregunta_analitica": "",  # TODO: ¿qué pregunta medible responde eso?
    "datos_necesarios": "",   # TODO: ¿qué datos necesitas? (usa tu mapa de fuentes)
    "metrica_de_exito": "",   # TODO: ¿cómo sabrás que respondiste la pregunta?
}

mi_proyecto

# %%
resumen = (
    f"En {mi_proyecto['contexto']}, el problema es que {mi_proyecto['problema']}. "
    f"La pregunta analítica que guiará el proyecto es: {mi_proyecto['pregunta_analitica']}. "
    f"Para responderla se necesita: {mi_proyecto['datos_necesarios']}. "
    f"Se considerará resuelto cuando: {mi_proyecto['metrica_de_exito']}."
)
print(resumen)

# %% [markdown]
# ## Cierre
#
# - Guarda una copia de este notebook en tu Google Drive.
# - El párrafo que acabas de generar es la **semilla de tu proyecto
#   integrador**: lo iremos refinando módulo a módulo.
# - Próxima sesión (Clase 3, virtual): fundamentos de estadística
#   descriptiva — empezamos a mirar tus datos con números.
